# %% [markdown]
# #### Task: Data Cleaning and Preprocessing
# * **Project Title:** Data Cleaning for a Real-world Dataset
# * **Description:** Choose a dataset with missing values, duplicates, and inconsistencies. Clean the data, handle missing values, and preprocess it for analysis.
# * **Dataset Reference:** World Health Organization (WHO) COVID-19 Dataset

# %% [markdown]
# #### 1. Load the Required Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### 2. Importing Data

# %%
df = pd.read_csv(r"C:\Users\smith\Downloads\2Datacleaning and prepocessing\CUserssmithDownloads2Datacleaning and prepocessing.csv")
df
# Out:
#            Country Country_code Who_region Wb_income  Year  Month Agegroup  \
# 0           Kuwait          KWT       EMRO       HIC  2025     12    15_64
# 1             Guam          GUM       WPRO       HIC  2025      2      65+
# 2             Guam          GUM       WPRO       HIC  2025      2     5_14
# 3             Guam          GUM       WPRO       HIC  2025      2    15_64
# 4             Guam          GUM       WPRO       HIC  2025      2      0_4
# ...            ...          ...        ...       ...   ...    ...      ...
# 67527       Mexico          MEX       AMRO       UMC  2020      3      0_4
# 67528       Mexico          MEX       AMRO       UMC  2020      2      65+
# 67529       Mexico          MEX       AMRO       UMC  2020      2     5_14
# 67530       Mexico          MEX       AMRO       UMC  2020      2      0_4
# 67531  Afghanistan          AFG       EMRO       LIC  2020      1      0_4
#
#        Deaths
# 0         NaN
# 1         NaN
# 2         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67532 entries, 0 to 67531
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       67532 non-null  object
#  1   Country_code  67532 non-null  object
#  2   Who_region    67028 non-null  object
#  3   Wb_income     52664 non-null  object
#  4   Year          67532 non-null  int64
#  5   Month         67532 non-null  int64
#  6   Agegroup      67532 non-null  object
#  7   Deaths        17575 non-null  float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 4.1+ MB

# %%
df.describe()
# Out:
#                Year         Month        Deaths
# count  67532.000000  67532.000000  17575.000000
# mean    2022.142688      6.428241    228.605292
# std        1.520728      3.553160   1746.961602
# min     2020.000000      1.000000      0.000000
# 25%     2021.000000      3.000000      0.000000
# 50%     2022.000000      6.000000      0.000000
# 75%     2023.000000     10.000000      8.000000
# max     2025.000000     12.000000  85228.000000

# %%
df.columns.values
# Out:
# array(['Country', 'Country_code', 'Who_region', 'Wb_income', 'Year',
#        'Month', 'Agegroup', 'Deaths'], dtype=object)

# %% [markdown]
# #### Description of the features
# **Country**:
#    - This column represents the name of the country in which the data was recorded. It likely corresponds to the geographic location where the COVID-19 statistics were gathered.
#
# **Country_code**:
#    - This column likely contains the ISO country code or another standardized code for the country. It serves as an identifier for countries.
#
# **Who_region**:
#    - This column may represent the region of the World Health Organization (WHO) to which the country belongs. WHO divides the world into several regions for reporting and analysis, such as "EURO" (European Region), "AFRO" (African Region), "AMRO" (American Region), "WPRO" (Western Pacific Region), "EMRO" (Eastern Mediterranean Region), and "SEARO" (South-East Asia Region).
#
# **Wb_income**:
#    - This column likely indicates the income classification of the country according to the World Bank, such as "HIC" (High-Income Countries), "UMC" (Upper-Middle-Income Countries), "LMC" (Lower-Middle-Income Countries), or "LIC" (Low-Income Countries). This classification helps categorize countries based on their gross national income (GNI).
#
# **Year**:
#    - This column records the year in which the data was collected, helping to track the progression of the COVID-19 pandemic over time.
#
# **Month**:
#    - This column represents the month within the year that the data was recorded. It helps provide more granular time-series data for analyzing trends and patterns in COVID-19 cases or deaths.
# **Agegroup**:
#    - This column may categorize the population by age group, such as "0-14", "15-64", and "65+" years. This data is often used to analyze how different age groups are affected by the disease.
#
# **Deaths**:
#    - This column represents the number of deaths attributed to COVID-19 in a given country, during the specified year and month, and for a specific age group (if relevant). It helps assess the severity and impact of the pandemic in each country.

# %%
# First few rows
print(df.head())
# Out:
#   Country Country_code Who_region Wb_income  Year  Month Agegroup  Deaths
# 0  Kuwait          KWT       EMRO       HIC  2025     12    15_64     NaN
# 1    Guam          GUM       WPRO       HIC  2025      2      65+     NaN
# 2    Guam          GUM       WPRO       HIC  2025      2     5_14     NaN
# 3    Guam          GUM       WPRO       HIC  2025      2    15_64     NaN
# 4    Guam          GUM       WPRO       HIC  2025      2      0_4     NaN

# %%
# Shape 
print(df.shape)
# Out:
# (67532, 8)

# %%
df.columns.values
# Out:
# array(['Country', 'Country_code', 'Who_region', 'Wb_income', 'Year',
#        'Month', 'Agegroup', 'Deaths', 'Date'], dtype=object)

# %%
#  data types
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67532 entries, 0 to 67531
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       67532 non-null  object
#  1   Country_code  67532 non-null  object
#  2   Who_region    67028 non-null  object
#  3   Wb_income     52664 non-null  object
#  4   Year          67532 non-null  int64
#  5   Month         67532 non-null  int64
#  6   Agegroup      67532 non-null  object
#  7   Deaths        17575 non-null  float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 4.1+ MB
# None

# %%
# Summary statistics
print(df.describe(include='all'))
# Out:
#        Country Country_code Who_region Wb_income          Year         Month  \
# count    67532        67532      67028     52664  67532.000000  67532.000000
# unique     268          268          7         4           NaN           NaN
# top     Kuwait          KWT       EURO       HIC           NaN           NaN
# freq       252          252      17136     18896           NaN           NaN
# mean       NaN          NaN        NaN       NaN   2022.142688      6.428241
# std        NaN          NaN        NaN       NaN      1.520728      3.553160
# min        NaN          NaN        NaN       NaN   2020.000000      1.000000
# 25%        NaN          NaN        NaN       NaN   2021.000000      3.000000
# 50%        NaN          NaN        NaN       NaN   2022.000000      6.000000
# 75%        NaN          NaN        NaN       NaN   2023.000000     10.000000
# max        NaN          NaN        NaN       NaN   2025.000000     12.000000
#
#        Agegroup        Deaths
# ...

# %% [markdown]
# #### 3. Finding and Handling Duplicate

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Handling Duplicate
# df.drop_duplicates(ignore_index = True, inplace = True)

# %% [markdown]
# #### 4. Checking and Handling Missing Values

# %%
# Count missing values
missing = df.isnull().sum()
print("Missing values per column:\n", missing)

# Visualize missing data
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values Heatmap")
plt.show()
# Out:
# Missing values per column:
#  Country             0
# Country_code        0
# Who_region        504
# Wb_income       14868
# Year                0
# Month               0
# Agegroup            0
# Deaths          49957
# dtype: int64

# %% [markdown]
# * The dataset has no missing values in key identifiers like Country, Country_code, Year, Month, and Agegroup, which means the time and country-specific grouping of the data remains reliable.
#
# * The Who_region column has 504 missing values, which is relatively low and may be manageable with imputation.
#
# * The Wb_income column has 14,868 missing values, suggesting a significant portion of countries/entries lack economic classification, which could affect analysis based on income groups.
#
# * The Deaths column has 49,957 missing values, which is substantial and may heavily impact any mortality-related analysis, possibly requiring imputation, exclusion, or separate modeling strategies to handle these missing values.

# %% [markdown]
# #### 5. Handle Missing Values
# Let’s specifically handle the 'Deaths' column which contains NaN.

# %%
# Fill with 0 (if NaN means no reported deaths)
df['Deaths'] = df['Deaths'].fillna(0)

# %%
# Replace null values in features 'Who_region' and 'Wb_income'
df[['Who_region', 'Wb_income']] = df[['Who_region', 'Wb_income']].fillna("unknown")

# %%
missing = df.isnull().sum()
print(missing)
# Out:
# Country         0
# Country_code    0
# Who_region      0
# Wb_income       0
# Year            0
# Month           0
# Agegroup        0
# Deaths          0
# Date            0
# dtype: int64

# %% [markdown]
# #### 6. Convert Data Types if Needed
# Make sure columns like Year, Month, and Deaths are the right types:

# %%
df['Year'] = df['Year'].astype(int)
df['Month'] = df['Month'].astype(int)
df['Deaths'] = df['Deaths'].astype(int)

# %% [markdown]
# #### 7. Check for Inconsistencies
# Check if Agegroup, Who_region, or Country columns have inconsistent formatting or typos.

# %%
print(df['Agegroup'].unique())
print(df['Who_region'].unique())
print(df['Country'].nunique())

# %%
# Standardize text :
df['Agegroup'] = df['Agegroup'].str.strip().str.replace(' ', '_')
df['Country'] = df['Country'].str.title()

# %% [markdown]
# #### 8. Basic Visualizations
# ##### A. Deaths Over Time

# %%
# Create a 'Date' column by combining 'Year' and 'Month' (assuming the 'Year' and 'Month' columns are integers)
df['Date'] = pd.to_datetime(df[['Year', 'Month']].assign(DAY=1))

# Group by 'Date' and sum 'Deaths'
df_grouped = df.groupby('Date')['Deaths'].sum().reset_index()

# Plotting
plt.figure(figsize=(14, 6))
sns.lineplot(data=df_grouped, x='Date', y='Deaths')
plt.title("Total Deaths Over Time")
plt.xlabel("Date")
plt.ylabel("Deaths")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Insights
# ##### Sharp Increase in Deaths in 2021:
#
# * Deaths Peaked in 2021, The highest mortality occurred in 2021, likely due to the Delta variant and pandemic-related healthcare strain.
#
# * Steady Decline After 2021, Deaths dropped in 2022  and in 2023, signaling reduced pandemic severity and improved health measures.
#
# * The absence of 2010–2020 figures makes it impossible to determine baseline trends or the full scale of excess deaths during the pandemic.

# %% [markdown]
# ##### B. Deaths by Region

# %%
plt.figure(figsize=(10, 6))
region_group = df.groupby('Who_region')['Deaths'].sum().sort_values(ascending=False)
sns.barplot(x=region_group.index, y=region_group.values)
plt.title("Total Deaths by WHO Region")
plt.ylabel("Deaths")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Top 5 Countries in Each Year Based on Deaths

# %%
# Group by Year and Country, summing total deaths
year_country_deaths = df.groupby(['Year', 'Country'])['Deaths'].sum().reset_index()

# For each year, get the top 5 countries with the highest deaths
top5_per_year = year_country_deaths.groupby('Year').apply(
    lambda x: x.nlargest(5, 'Deaths')
).reset_index(drop=True)

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(data=top5_per_year, x='Year', y='Deaths', hue='Country')
plt.title('Top 5 Countries by Deaths per Year')
plt.xlabel('Year')
plt.ylabel('Total Deaths')
plt.xticks(rotation=45)
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\smith\AppData\Local\Temp\ipykernel_5000\181827021.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top5_per_year = year_country_deaths.groupby('Year').apply(

# %% [markdown]
# #### Conclusion
# i. The USA consistently ranks as the top country with the highest number of deaths each year, especially during the years 2020 to 2022, showing a peak around 2021.
#
# ii. Significant Drop Over Time There is a clear and sharp decline in total deaths across most countries after 2022. This may reflect the impact of:
#
# * Widespread vaccination,
#
# * Improved healthcare responses,
#
# * Better awareness and control measures.
#
# iii. High Death Toll in 2020–2021 for Latin American Countries Countries such as Brazil, Mexico, and Peru appear prominently in the top 5 during 2020 and 2021, reflecting how severely they were affected in the earlier phase of the pandemic.
#
# iv. Emergence of European Countries in Later Years After 2022, European countries like Italy, Germany, France, and Spain start to appear in the top 5, although with relatively lower death counts than earlier leaders.
#
# v. Low Death Counts in 2024 and 2025 The trend suggests that by 2024 and 2025, deaths have become significantly lower globally, with no single country experiencing a dramatic spike.

# %%
# Group by Year and WHO Region, summing deaths
region_year_deaths = df.groupby(['Year', 'Who_region'])['Deaths'].sum().reset_index()

# Get top 5 regions per year
top5_regions_per_year = region_year_deaths.groupby('Year').apply(lambda x: x.nlargest(5, 'Deaths')).reset_index(drop=True)

# Plot using FacetGrid
g = sns.FacetGrid(top5_regions_per_year, col='Year', col_wrap=3, height=4, sharex=False, sharey=False)
g.map_dataframe(sns.barplot, x='Deaths', y='Who_region', hue='Who_region', palette='Reds_d', legend=False)
g.set_titles("Top 5 WHO Regions in {col_name}")
g.set_axis_labels("Total Deaths", "WHO Region")
g.tight_layout()
plt.show()
# Out:
# C:\Users\smith\AppData\Local\Temp\ipykernel_5000\3243776467.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top5_regions_per_year = region_year_deaths.groupby('Year').apply(lambda x: x.nlargest(5, 'Deaths')).reset_index(drop=True)

# %% [markdown]
# ##### Based on the bar chart displayed:
#
# * AMRO (Region of the Americas) had the highest number of total deaths, significantly more than any other region. This suggests that the Americas—especially countries like the USA and Brazil—experienced the most severe impact in terms of mortality.
#
# * EURO (European Region) follows closely behind AMRO, showing a very high death toll, likely influenced by major outbreaks in countries like the UK, Italy, and France during peak pandemic periods.
#
# * WPRO (Western Pacific Region) ranks third, but with a much smaller number of deaths compared to AMRO and EURO, indicating better containment or fewer outbreaks in countries like Japan, South Korea, and Australia.
#
# * SEARO (South-East Asia Region) and EMRO (Eastern Mediterranean Region) are also in the top five but contribute relatively small proportions of the total deaths. These could reflect varying levels of healthcare infrastructure, population age distribution, or reporting accuracy.

# %% [markdown]
# ##### C. Deaths by Age Group

# %%
plt.figure(figsize=(10, 6))
age_group = df.groupby('Agegroup')['Deaths'].sum().sort_values(ascending=False)
sns.barplot(x=age_group.index, y=age_group.values)
plt.title("Total Deaths by Age Group")
plt.ylabel("Deaths")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# * The data reveals a clear age-dependent pattern in COVID-19 mortality, with the highest death rates observed among individuals aged 65 and older. This demographic faced the most severe outcomes due to factors such as weakened immune systems, and increased vulnerability to severe respiratory complications.
#
# * Following this group, the next most affected age range was 15_64 years old. While younger adults and middle-aged individuals generally had better survival rates, deaths in this group were still significant, particularly among those with underlying health conditions, limited healthcare access, or occupational exposure risks.

# %% [markdown]
# ##### Top top 5 death years in each Agegroup (Death Count)
# We interpret this as the years that have the most diverse or numerous age group entries with associated deaths.

# %%
# Group by Year and Agegroup, then sum total deaths
year_agegroup_deaths = df.groupby(['Year', 'Agegroup'])['Deaths'].sum().reset_index()

# Get top 5 death entries in each Agegroup across all years
top5_deaths_per_agegroup_year = year_agegroup_deaths.groupby('Agegroup').apply(
    lambda x: x.nlargest(5, 'Deaths')
).reset_index(drop=True)

# Plot
plt.figure(figsize=(14, 6))
sns.barplot(data=top5_deaths_per_agegroup_year, x='Agegroup', y='Deaths', hue='Year', palette='Set2')
plt.title('Top 5 Years with Highest Deaths in Each Agegroup')
plt.ylabel('Total Deaths')
plt.xlabel('Agegroup')
plt.legend(title='Year', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\smith\AppData\Local\Temp\ipykernel_16684\1361481242.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top5_deaths_per_agegroup_year = year_agegroup_deaths.groupby('Agegroup').apply(

# %% [markdown]
# ###### Based on the graph "Top 5 Years with Highest Deaths in Each Age Group," the following conclusions can be drawn:
#
# 1. **Year with Highest Deaths**: The year **2021** recorded the highest number of deaths across all age groups.
#
# 2. **Age Groups Affected**:
#    - The age groups listed are **5-14**, **15-64**, and **65+**.
#    - The graph implies that **2021** had the highest deaths in all these groups, but specifically high for ages 15_64 and 65+.

# %% [markdown]
# ##### Top 5 Countries by Deaths Each Month in 2021

# %%
# Filter data for the year 2021
df_2021 = df[df['Year'] == 2021]

# Group by Month and Country to get the total deaths
month_country_deaths = df_2021.groupby(['Month', 'Country'])['Deaths'].sum().reset_index()

# Get top 5 countries per month
top5_months = month_country_deaths.groupby('Month').apply(lambda x: x.nlargest(5, 'Deaths')).reset_index(drop=True)

# Plot
plt.figure(figsize=(14, 6))
sns.barplot(data=top5_months, x='Month', y='Deaths', hue='Country')
plt.title('Top 5 Countries by Deaths per Month in 2021')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\smith\AppData\Local\Temp\ipykernel_16684\3031873071.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top5_months = month_country_deaths.groupby('Month').apply(lambda x: x.nlargest(5, 'Deaths')).reset_index(drop=True)

# %% [markdown]
# * The United States and Mexico consistently had the highest number of deaths in the 1st, 2nd, 8th, and 9th month in 2021.
#
# * As we investigate above 2021 was a peak pandemic year with variants like Delta causing surges.
#
# * In the 4th, 5th, and 6th month of 2021 death rate was high at Peru, Colombia, Argentina.
#
# * There was a high death in the 3rd month of 2021 at Brazil.

# %% [markdown]
# #### 9. Encoding Categorical Variables

# %%
# Remove columns which is not relevant to the analysis, for example, Country_code
df=df.drop(columns=['Date', 'Country_code'])

# %% [markdown]
# * Encoding categorical variables is a critical step in data preprocessing for machine learning models, as most models require numerical input.
# ##### There are two approach:
# * **Label encoding** and **one-hot encoding.**
# **Label Encoding**
# * It converts each category in a categorical variable to a unique integer.
#
# **When to Use:** When the categorical variable has an ordinal relationship (e.g., low, medium, high).
# * When there are a limited number of categories.
#
# **One-Hot Encoding**
# * One-hot encoding converts categorical variables into a series of binary columns, each representing a unique category.
#
# **When to Use**
#
# * When the categorical variable is nominal (no intrinsic order).
# * When you want to avoid introducing ordinal relationships.

# %%
from sklearn.preprocessing import LabelEncoder

# One-hot encode categorical columns: 'Country' and 'Who_region'
df_encoded = pd.get_dummies(df, columns=['Country', 'Who_region'], drop_first=True)

# Initialize LabelEncoder
le = LabelEncoder()

# Apply label encoding to 'Wb_income' and 'Agegroup'
df_encoded['Wb_income'] = le.fit_transform(df_encoded['Wb_income'].replace('unknown', '0'))  # Replace 'unknown' with '0' to avoid errors
df_encoded['Agegroup'] = le.fit_transform(df_encoded['Agegroup'])

# Check the result
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67532 entries, 0 to 67531
# Columns: 279 entries, Wb_income to Who_region_unknown
# dtypes: bool(274), int32(5)
# memory usage: 18.9 MB

# %% [markdown]
# #### 10. Save Cleaned Dataset

# %%
# data before encoded
df.to_csv("cleaned_covid_data.csv", index=False)

#data after encoded
df_encoded.to_csv("cleaned_covid_data1.csv", index=False)

# %% [markdown]
# #### 11. Conclusion
#
# 1. The Deaths column has 49,957 missing values, which is substantial and could significantly affect any mortality-related analysis. Instead of dropping this important feature, a more practical approach may be to fill the missing values with zero, assuming that the absence of reported deaths indicates no recorded fatalities. This allows for a more inclusive analysis without losing valuable data points, especially when studying trends across countries, age groups, or time periods.
# 2. Deaths peaked in 2021, with the highest mortality likely driven by the widespread impact of the Delta variant and the increased strain on healthcare systems during the height of the pandemic.
# 3. According to the WHO Dataset, the AMRO region recorded the highest death rate among all regions.
# 4. The USA consistently reported the highest number of deaths each year, particularly between 2020 and 2022, with a noticeable peak in 2021.
# 5. The data shows a clear age-related trend in COVID-19 mortality, with the highest death rates among individuals aged 65 and above. This group experienced the most severe outcomes, largely due to weakened immune systems and a higher susceptibility to serious respiratory complications.
# 6. The highest number of deaths was recorded in 2021, with January of that year marking the peak month for fatalities.
